# %% [markdown]
# # Prediction with Facebook Prophet

# %%
from stocker import Stocker
import quandl
import matplotlib.pyplot as plt

# %%
# Quandl API key
quandl.ApiConfig.api_key = "ykjGjY8xpsA1_sM1Y84q"


# MSFT is in the WIKI database, which is default
microsoft = Stocker(ticker='MSFT')

# TECHM is in the NSE database
techm = Stocker(ticker='TECHM', exchange='NSE')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 00:00:00 to 2018-03-27 00:00:00.
# TECHM Stocker Initialized. Data covers 2006-08-28 00:00:00 to 2019-01-04 00:00:00.

# %%
microsoft.plot_stock(start_date=None, end_date=None, stats=['Adj. Close'], plot_type='basic')
# Out:
# Maximum Adj. Close = 96.77 on 2018-03-12 00:00:00.
# Minimum Adj. Close = 0.06 on 1986-03-24 00:00:00.
# Current Adj. Close = 89.47 on 2018-03-27 00:00:00.

# %%
microsoft.buy_and_hold(start_date=None, end_date=None, nshares=1)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 00:00:00 to 2018-03-27 00:00:00 for 1 shares = $89.41

# %%
model, future = microsoft.create_prophet_model(days=200, resample=False)
# Out:
# Predicted Price on 2018-10-13 00:00:00 = $107.32

# %%
model.plot_components(future)
